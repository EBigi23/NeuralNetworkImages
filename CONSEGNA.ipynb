# %% [markdown]
# **Import necessari**

# %%
import os
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Dropout, concatenate, UpSampling2D
from tensorflow.keras import models
from tensorflow.keras import losses
from tensorflow.keras import optimizers
import numpy as np
import random
from cv2 import GaussianBlur

# %% [markdown]
# **Funzioni utilizzate**

# %%
def getDataset():
    (x_train, _), (x_test, _) = tf.keras.datasets.cifar10.load_data()
    normalize = lambda x: x/x.max()
    x_train = normalize(x_train)
    x_test = normalize(x_test)
    createBlurred = lambda arr: np.array([GaussianBlur(x, (5,5), ((random.random()*3)+1)) + (0.02*np.random.normal(0,1, (32, 32, 3))) for x in arr])
    return (createBlurred(x_train), x_train), (createBlurred(x_test), x_test)

# %% [markdown]
# **Definizione del modello**

# %%
# La funzione UNet definisce l'architettura della rete neurale U-Net.
# Prende in input una forma di input (input_shape) e restituisce un modello Keras

def UNet(input_shape):
    keras.backend.clear_session()
    inputs = Input(input_shape)

    # Encoder
    # L'encoder inizia con due blocchi di convoluzione consecutivi (conv1) seguiti
    # da un max pooling (pool1). I parametri utilizzati per le convoluzioni sono:
    # - 16 filtri
    # - Dimensione del kernel 3x3
    # - Funzione di attivazione ReLU
    # - Padding "same" per mantenere le dimensioni
    # - Inizializzazione dei pesi con l'inizializzatore "he_normal"
    conv1 = Conv2D(16, 3, activation='relu', padding='same', kernel_initializer='he_normal')(inputs)
    conv1 = Conv2D(16, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    # Il secondo blocco (conv2) segue lo stesso schema del primo, con 32 filtri
    conv2 = Conv2D(32, 3, activation='relu', padding='same', kernel_initializer='he_normal')(pool1)
    conv2 = Conv2D(32, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    # Il terzo blocco (conv3) ha 64 filtri
    conv3 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer='he_normal')(pool2)
    conv3 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    # Il quarto blocco (conv4) ha ancora 64 filtri e
    # un dropout del 25% dopo la seconda convoluzione
    conv4 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer='he_normal')(pool3)
    conv4 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv4)
    drop4 = Dropout(0.25)(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

    # Bottleneck
    # Il blocco del bottleneck (conv5) ha 64 filtri ed è seguito da un dropout del 25%
    conv5 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer='he_normal')(pool4)
    conv5 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv5)
    drop5 = Dropout(0.25)(conv5)

    # Decoder
    # Il primo blocco di decodifica (up6) utilizza un'operazione di upsampling
    # per aumentare le dimensioni dell'immagine seguita da una convoluzione con 64 filtri.
    # Il risultato viene concatenato con il quarto blocco di convoluzione (drop4) tramite l'operazione concatenate.
    # Seguono due convoluzioni aggiuntive (conv6) con 64 filtri ciascuna.
    up6 = Conv2D(64, 2, activation='relu', padding='same', kernel_initializer='he_normal')(UpSampling2D(size=(2, 2))(drop5))
    merge6 = concatenate([drop4, up6], axis=3)
    conv6 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer='he_normal')(merge6)
    conv6 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv6)

    # Il secondo blocco di decodifica (up7) utilizza un'operazione di upsampling
    # seguita da una convoluzione con 32 filtri. Il risultato viene concatenato
    # con il terzo blocco di convoluzione (conv3).
    # Vengono poi applicate due convoluzioni (conv7) con 32 filtri ciascuna.
    up7 = Conv2D(32, 2, activation='relu', padding='same', kernel_initializer='he_normal')(UpSampling2D(size=(2, 2))(conv6))
    merge7 = concatenate([conv3, up7], axis=3)
    conv7 = Conv2D(32, 3, activation='relu', padding='same', kernel_initializer='he_normal')(merge7)
    conv7 = Conv2D(32, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv7)

    # Il terzo blocco di decodifica (up8) utilizza un'operazione di upsampling
    # seguita da una convoluzione con 16 filtri. Il risultato viene concatenato
    # con il secondo blocco di convoluzione (conv2).
    # Seguono due convoluzioni (conv8) con 16 filtri ciascuna.
    up8 = Conv2D(16, 2, activation='relu', padding='same', kernel_initializer='he_normal')(UpSampling2D(size=(2, 2))(conv7))
    merge8 = concatenate([conv2, up8], axis=3)
    conv8 = Conv2D(16, 3, activation='relu', padding='same', kernel_initializer='he_normal')(merge8)
    conv8 = Conv2D(16, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv8)

    # Il quarto blocco di decodifica (up9) utilizza un'operazione di upsampling
    # seguita da una convoluzione con 8 filtri. Il risultato viene concatenato
    # con il primo blocco di convoluzione (conv1).
    # Seguono due convoluzioni (conv9) con 8 filtri ciascuna.
    up9 = Conv2D(8, 2, activation='relu', padding='same', kernel_initializer='he_normal')(UpSampling2D(size=(2, 2))(conv8))
    merge9 = concatenate([conv1, up9], axis=3)
    conv9 = Conv2D(8, 3, activation='relu', padding='same', kernel_initializer='he_normal')(merge9)
    conv9 = Conv2D(8, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv9)

    # Output
    # L'output finale è ottenuto applicando una convoluzione con 3 filtri e una
    # dimensione del kernel di 3x3. Successivamente, viene applicata una convoluzione
    # con 1 filtro e una dimensione del kernel di 1x1 per ottenere il risultato finale dell'immagine ricostruita.
    conv9 = Conv2D(3, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv9)
    outputs = layers.Conv2D(3, 1, activation='sigmoid')(conv9)

    model = keras.Model(inputs=inputs, outputs=outputs, name='UNet')
    model.summary()

    return model

# %% [markdown]
# **Fase di training del modello**

# %%
# Carico e pre-elaboro i dati
(x_train, y_train), (x_test, y_test) = getDataset()

# Suddivido il dataset di addestramento in train e validation set
val_split = 0.05
val_samples = int(val_split * len(x_train))
X_val = x_train[-val_samples:]
y_val = y_train[-val_samples:]
x_train = x_train[:val_samples]
y_train = y_train[:val_samples]

model = UNet((32, 32, 3))

EPOCHS = 100
BATCH_SIZE = 32  # Riduci la dimensione del batch
callbacks=[keras.callbacks.ModelCheckpoint('pesi_rete.h5',save_best_only=True)]

# Aggiungo un learning rate scheduler
lr_scheduler = keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=5)

model.compile(optimizer=optimizers.Adam(),
              loss=losses.MeanSquaredError(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    validation_data=(X_val, y_val),
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS,
                    callbacks=[callbacks],
                    verbose=1)
# Out:
# (50000, 32, 32, 3)
# (50000, 32, 32, 3)
# Model: "UNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 32, 32, 16)   448         ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 32, 32, 16)   2320        ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 16, 16, 16)   0           ['conv2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 16, 16, 32)   4640        ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 16, 16, 32)   9248        ['conv2d_2[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 8, 8, 32)    0           ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 8, 8, 64)     18496       ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 8, 8, 64)     36928       ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 4, 4, 64)    0           ['conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 4, 4, 64)     36928       ['max_pooling2d_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 4, 4, 64)     36928       ['conv2d_6[0][0]']
#
#  dropout (Dropout)              (None, 4, 4, 64)     0           ['conv2d_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 2, 2, 64)    0           ['dropout[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 2, 2, 64)     36928       ['max_pooling2d_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 2, 2, 64)     36928       ['conv2d_8[0][0]']
#
#  dropout_1 (Dropout)            (None, 2, 2, 64)     0           ['conv2d_9[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 4, 4, 64)     0           ['dropout_1[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 4, 4, 64)     16448       ['up_sampling2d[0][0]']
#
#  concatenate (Concatenate)      (None, 4, 4, 128)    0           ['dropout[0][0]',
#                                                                   'conv2d_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 4, 4, 64)     73792       ['concatenate[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 4, 4, 64)     36928       ['conv2d_11[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 8, 8, 64)    0           ['conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 8, 8, 32)     8224        ['up_sampling2d_1[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 8, 8, 96)     0           ['conv2d_5[0][0]',
#                                                                   'conv2d_13[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 8, 8, 32)     27680       ['concatenate_1[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 8, 8, 32)     9248        ['conv2d_14[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 16, 16, 32)  0           ['conv2d_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 16, 16, 16)   2064        ['up_sampling2d_2[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 16, 16, 48)   0           ['conv2d_3[0][0]',
#                                                                   'conv2d_16[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 16, 16, 16)   6928        ['concatenate_2[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 16, 16, 16)   2320        ['conv2d_17[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 32, 32, 16)  0           ['conv2d_18[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 32, 32, 8)    520         ['up_sampling2d_3[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 32, 32, 24)   0           ['conv2d_1[0][0]',
#                                                                   'conv2d_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 32, 32, 8)    1736        ['concatenate_3[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 32, 32, 8)    584         ['conv2d_20[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 32, 32, 3)    219         ['conv2d_21[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 32, 32, 3)    12          ['conv2d_22[0][0]']
#
# ==================================================================================================
# Total params: 406,495
# Trainable params: 406,495
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/100
# 79/79 [==============================] - 39s 440ms/step - loss: 0.0476 - accuracy: 0.4223 - val_loss: 0.0347 - val_accuracy: 0.4426
# Epoch 2/100
# 79/79 [==============================] - 30s 384ms/step - loss: 0.0292 - accuracy: 0.4542 - val_loss: 0.0248 - val_accuracy: 0.4734
# Epoch 3/100
# 79/79 [==============================] - 34s 438ms/step - loss: 0.0223 - accuracy: 0.5129 - val_loss: 0.0191 - val_accuracy: 0.5595
# Epoch 4/100
# 79/79 [==============================] - 29s 365ms/step - loss: 0.0119 - accuracy: 0.5367 - val_loss: 0.0074 - val_accuracy: 0.5374
# Epoch 5/100
# 79/79 [==============================] - 29s 369ms/step - loss: 0.0072 - accuracy: 0.5526 - val_loss: 0.0068 - val_accuracy: 0.5441
# Epoch 6/100
# 79/79 [==============================] - 34s 434ms/step - loss: 0.0067 - accuracy: 0.5592 - val_loss: 0.0066 - val_accuracy: 0.5945
# Epoch 7/100
# 79/79 [==============================] - 29s 365ms/step - loss: 0.0064 - accuracy: 0.5658 - val_loss: 0.0062 - val_accuracy: 0.5443
# Epoch 8/100
# 79/79 [==============================] - 29s 366ms/step - loss: 0.0062 - accuracy: 0.5649 - val_loss: 0.0060 - val_accuracy: 0.5468
# Epoch 9/100
# 79/79 [==============================] - 30s 380ms/step - loss: 0.0060 - accuracy: 0.5684 - val_loss: 0.0060 - val_accuracy: 0.5659
# Epoch 10/100
# 79/79 [==============================] - 33s 417ms/step - loss: 0.0059 - accuracy: 0.5688 - val_loss: 0.0060 - val_accuracy: 0.5566
# Epoch 11/100
# 79/79 [==============================] - 29s 363ms/step - loss: 0.0058 - accuracy: 0.5775 - val_loss: 0.0056 - val_accuracy: 0.6034
# Epoch 12/100
# 79/79 [==============================] - 29s 370ms/step - loss: 0.0056 - accuracy: 0.5929 - val_loss: 0.0055 - val_accuracy: 0.6000
# Epoch 13/100
# 79/79 [==============================] - 34s 425ms/step - loss: 0.0053 - accuracy: 0.6195 - val_loss: 0.0053 - val_accuracy: 0.6520
# Epoch 14/100
# 79/79 [==============================] - 29s 369ms/step - loss: 0.0053 - accuracy: 0.6496 - val_loss: 0.0050 - val_accuracy: 0.6572
# Epoch 15/100
# 79/79 [==============================] - 29s 367ms/step - loss: 0.0050 - accuracy: 0.6810 - val_loss: 0.0050 - val_accuracy: 0.6784
# Epoch 16/100
# 79/79 [==============================] - 30s 376ms/step - loss: 0.0049 - accuracy: 0.7002 - val_loss: 0.0047 - val_accuracy: 0.7141
# Epoch 17/100
# 79/79 [==============================] - 33s 416ms/step - loss: 0.0047 - accuracy: 0.7227 - val_loss: 0.0046 - val_accuracy: 0.7347
# Epoch 18/100
# 79/79 [==============================] - 29s 367ms/step - loss: 0.0046 - accuracy: 0.7345 - val_loss: 0.0048 - val_accuracy: 0.7423
# Epoch 19/100
# 79/79 [==============================] - 32s 404ms/step - loss: 0.0047 - accuracy: 0.7336 - val_loss: 0.0045 - val_accuracy: 0.7391
# Epoch 20/100
# 79/79 [==============================] - 33s 414ms/step - loss: 0.0045 - accuracy: 0.7455 - val_loss: 0.0046 - val_accuracy: 0.7491
# Epoch 21/100
# 79/79 [==============================] - 29s 367ms/step - loss: 0.0044 - accuracy: 0.7521 - val_loss: 0.0043 - val_accuracy: 0.7488
# Epoch 22/100
# 79/79 [==============================] - 34s 434ms/step - loss: 0.0044 - accuracy: 0.7561 - val_loss: 0.0043 - val_accuracy: 0.7541
# Epoch 23/100
# 79/79 [==============================] - 29s 364ms/step - loss: 0.0043 - accuracy: 0.7612 - val_loss: 0.0042 - val_accuracy: 0.7655
# Epoch 24/100
# 79/79 [==============================] - 29s 368ms/step - loss: 0.0043 - accuracy: 0.7655 - val_loss: 0.0042 - val_accuracy: 0.7596
# Epoch 25/100
# 79/79 [==============================] - 34s 434ms/step - loss: 0.0043 - accuracy: 0.7644 - val_loss: 0.0041 - val_accuracy: 0.7689
# Epoch 26/100
# 79/79 [==============================] - 28s 361ms/step - loss: 0.0042 - accuracy: 0.7704 - val_loss: 0.0041 - val_accuracy: 0.7719
# Epoch 27/100
# 79/79 [==============================] - 30s 384ms/step - loss: 0.0042 - accuracy: 0.7715 - val_loss: 0.0041 - val_accuracy: 0.7646
# Epoch 28/100
# 79/79 [==============================] - 29s 367ms/step - loss: 0.0041 - accuracy: 0.7744 - val_loss: 0.0040 - val_accuracy: 0.7776
# Epoch 29/100
# 79/79 [==============================] - 30s 373ms/step - loss: 0.0040 - accuracy: 0.7782 - val_loss: 0.0040 - val_accuracy: 0.7797
# Epoch 30/100
# 79/79 [==============================] - 33s 419ms/step - loss: 0.0041 - accuracy: 0.7788 - val_loss: 0.0040 - val_accuracy: 0.7745
# Epoch 31/100
# 79/79 [==============================] - 29s 363ms/step - loss: 0.0040 - accuracy: 0.7767 - val_loss: 0.0041 - val_accuracy: 0.7745
# Epoch 32/100
# 79/79 [==============================] - 30s 379ms/step - loss: 0.0040 - accuracy: 0.7817 - val_loss: 0.0041 - val_accuracy: 0.7835
# Epoch 33/100
# 79/79 [==============================] - 29s 364ms/step - loss: 0.0039 - accuracy: 0.7801 - val_loss: 0.0039 - val_accuracy: 0.7876
# Epoch 34/100
# 79/79 [==============================] - 29s 367ms/step - loss: 0.0039 - accuracy: 0.7844 - val_loss: 0.0045 - val_accuracy: 0.7461
# Epoch 35/100
# 79/79 [==============================] - 30s 387ms/step - loss: 0.0040 - accuracy: 0.7826 - val_loss: 0.0040 - val_accuracy: 0.7790
# Epoch 36/100
# 79/79 [==============================] - 30s 380ms/step - loss: 0.0039 - accuracy: 0.7867 - val_loss: 0.0039 - val_accuracy: 0.7816
# Epoch 37/100
# 79/79 [==============================] - 33s 415ms/step - loss: 0.0038 - accuracy: 0.7885 - val_loss: 0.0039 - val_accuracy: 0.7926
# Epoch 38/100
# 79/79 [==============================] - 29s 363ms/step - loss: 0.0038 - accuracy: 0.7882 - val_loss: 0.0040 - val_accuracy: 0.7924
# Epoch 39/100
# 79/79 [==============================] - 34s 434ms/step - loss: 0.0038 - accuracy: 0.7889 - val_loss: 0.0039 - val_accuracy: 0.7827
# Epoch 40/100
# 79/79 [==============================] - 29s 368ms/step - loss: 0.0038 - accuracy: 0.7900 - val_loss: 0.0038 - val_accuracy: 0.7897
# Epoch 41/100
# 79/79 [==============================] - 29s 364ms/step - loss: 0.0037 - accuracy: 0.7903 - val_loss: 0.0038 - val_accuracy: 0.7846
# Epoch 42/100
# 79/79 [==============================] - 29s 372ms/step - loss: 0.0038 - accuracy: 0.7876 - val_loss: 0.0039 - val_accuracy: 0.7917
# Epoch 43/100
# 79/79 [==============================] - 31s 389ms/step - loss: 0.0037 - accuracy: 0.7911 - val_loss: 0.0039 - val_accuracy: 0.7577
# Epoch 44/100
# 79/79 [==============================] - 33s 426ms/step - loss: 0.0037 - accuracy: 0.7921 - val_loss: 0.0038 - val_accuracy: 0.8014
# Epoch 45/100
# 79/79 [==============================] - 34s 431ms/step - loss: 0.0037 - accuracy: 0.7943 - val_loss: 0.0039 - val_accuracy: 0.7924
# Epoch 46/100
# 79/79 [==============================] - 28s 362ms/step - loss: 0.0036 - accuracy: 0.7940 - val_loss: 0.0038 - val_accuracy: 0.7984
# Epoch 47/100
# 79/79 [==============================] - 29s 369ms/step - loss: 0.0037 - accuracy: 0.7946 - val_loss: 0.0038 - val_accuracy: 0.7912
# Epoch 48/100
# 79/79 [==============================] - 34s 433ms/step - loss: 0.0036 - accuracy: 0.7963 - val_loss: 0.0038 - val_accuracy: 0.8002
# Epoch 49/100
# 79/79 [==============================] - 29s 368ms/step - loss: 0.0036 - accuracy: 0.7969 - val_loss: 0.0038 - val_accuracy: 0.8036
# Epoch 50/100
# 79/79 [==============================] - 29s 367ms/step - loss: 0.0036 - accuracy: 0.7958 - val_loss: 0.0038 - val_accuracy: 0.8047
# Epoch 51/100
# 79/79 [==============================] - 32s 401ms/step - loss: 0.0035 - accuracy: 0.7985 - val_loss: 0.0038 - val_accuracy: 0.8027
# Epoch 52/100
# 79/79 [==============================] - 33s 415ms/step - loss: 0.0035 - accuracy: 0.8000 - val_loss: 0.0039 - val_accuracy: 0.8048
# Epoch 53/100
# 79/79 [==============================] - 29s 367ms/step - loss: 0.0036 - accuracy: 0.7984 - val_loss: 0.0039 - val_accuracy: 0.7947
# Epoch 54/100
# 79/79 [==============================] - 30s 381ms/step - loss: 0.0035 - accuracy: 0.7997 - val_loss: 0.0037 - val_accuracy: 0.8038
# Epoch 55/100
# 79/79 [==============================] - 33s 415ms/step - loss: 0.0035 - accuracy: 0.7992 - val_loss: 0.0037 - val_accuracy: 0.8033
# Epoch 56/100
# 79/79 [==============================] - 29s 364ms/step - loss: 0.0034 - accuracy: 0.8015 - val_loss: 0.0037 - val_accuracy: 0.8074
# Epoch 57/100
# 79/79 [==============================] - 34s 433ms/step - loss: 0.0034 - accuracy: 0.8028 - val_loss: 0.0038 - val_accuracy: 0.8083
# Epoch 58/100
# 79/79 [==============================] - 29s 364ms/step - loss: 0.0035 - accuracy: 0.7998 - val_loss: 0.0037 - val_accuracy: 0.8015
# Epoch 59/100
# 79/79 [==============================] - 29s 363ms/step - loss: 0.0034 - accuracy: 0.8037 - val_loss: 0.0037 - val_accuracy: 0.7972
# Epoch 60/100
# 79/79 [==============================] - 29s 369ms/step - loss: 0.0034 - accuracy: 0.8040 - val_loss: 0.0037 - val_accuracy: 0.7896
# Epoch 61/100
# 79/79 [==============================] - 34s 424ms/step - loss: 0.0033 - accuracy: 0.8047 - val_loss: 0.0037 - val_accuracy: 0.8031
# Epoch 62/100
# 79/79 [==============================] - 29s 370ms/step - loss: 0.0033 - accuracy: 0.8051 - val_loss: 0.0037 - val_accuracy: 0.8048
# Epoch 63/100
# 79/79 [==============================] - 29s 370ms/step - loss: 0.0033 - accuracy: 0.8045 - val_loss: 0.0037 - val_accuracy: 0.7955
# Epoch 64/100
# 79/79 [==============================] - 34s 426ms/step - loss: 0.0033 - accuracy: 0.8061 - val_loss: 0.0037 - val_accuracy: 0.8012
# Epoch 65/100
# 79/79 [==============================] - 29s 365ms/step - loss: 0.0033 - accuracy: 0.8036 - val_loss: 0.0037 - val_accuracy: 0.8022
# Epoch 66/100
# 79/79 [==============================] - 29s 368ms/step - loss: 0.0033 - accuracy: 0.8048 - val_loss: 0.0039 - val_accuracy: 0.7924
# Epoch 67/100
# 79/79 [==============================] - 34s 434ms/step - loss: 0.0032 - accuracy: 0.8068 - val_loss: 0.0036 - val_accuracy: 0.8092
# Epoch 68/100
# 79/79 [==============================] - 29s 363ms/step - loss: 0.0032 - accuracy: 0.8035 - val_loss: 0.0037 - val_accuracy: 0.8014
# Epoch 69/100
# 79/79 [==============================] - 29s 368ms/step - loss: 0.0033 - accuracy: 0.8040 - val_loss: 0.0037 - val_accuracy: 0.8101
# Epoch 70/100
# 79/79 [==============================] - 34s 435ms/step - loss: 0.0032 - accuracy: 0.8083 - val_loss: 0.0037 - val_accuracy: 0.8102
# Epoch 71/100
# 79/79 [==============================] - 29s 372ms/step - loss: 0.0032 - accuracy: 0.8097 - val_loss: 0.0039 - val_accuracy: 0.8146
# Epoch 72/100
# 79/79 [==============================] - 30s 386ms/step - loss: 0.0031 - accuracy: 0.8079 - val_loss: 0.0037 - val_accuracy: 0.8117
# Epoch 73/100
# 79/79 [==============================] - 30s 380ms/step - loss: 0.0031 - accuracy: 0.8097 - val_loss: 0.0037 - val_accuracy: 0.8115
# Epoch 74/100
# 79/79 [==============================] - 29s 366ms/step - loss: 0.0031 - accuracy: 0.8115 - val_loss: 0.0037 - val_accuracy: 0.8006
# Epoch 75/100
# 79/79 [==============================] - 30s 375ms/step - loss: 0.0031 - accuracy: 0.8120 - val_loss: 0.0037 - val_accuracy: 0.8077
# Epoch 76/100
# 79/79 [==============================] - 29s 364ms/step - loss: 0.0031 - accuracy: 0.8107 - val_loss: 0.0036 - val_accuracy: 0.8129
# Epoch 77/100
# 79/79 [==============================] - 34s 434ms/step - loss: 0.0031 - accuracy: 0.8129 - val_loss: 0.0036 - val_accuracy: 0.8008
# Epoch 78/100
# 79/79 [==============================] - 29s 369ms/step - loss: 0.0032 - accuracy: 0.8076 - val_loss: 0.0036 - val_accuracy: 0.8095
# Epoch 79/100
# 79/79 [==============================] - 29s 369ms/step - loss: 0.0030 - accuracy: 0.8126 - val_loss: 0.0036 - val_accuracy: 0.8169
# Epoch 80/100
# 79/79 [==============================] - 36s 462ms/step - loss: 0.0030 - accuracy: 0.8120 - val_loss: 0.0037 - val_accuracy: 0.8153
# Epoch 81/100
# 79/79 [==============================] - 35s 446ms/step - loss: 0.0030 - accuracy: 0.8117 - val_loss: 0.0036 - val_accuracy: 0.8174
# Epoch 82/100
# 79/79 [==============================] - 32s 411ms/step - loss: 0.0031 - accuracy: 0.8131 - val_loss: 0.0037 - val_accuracy: 0.8112
# Epoch 83/100
# 79/79 [==============================] - 30s 379ms/step - loss: 0.0030 - accuracy: 0.8140 - val_loss: 0.0037 - val_accuracy: 0.8149
# Epoch 84/100
# 79/79 [==============================] - 34s 427ms/step - loss: 0.0031 - accuracy: 0.8133 - val_loss: 0.0036 - val_accuracy: 0.7944
# Epoch 85/100
# 79/79 [==============================] - 29s 367ms/step - loss: 0.0030 - accuracy: 0.8130 - val_loss: 0.0036 - val_accuracy: 0.8149
# Epoch 86/100
# 79/79 [==============================] - 30s 383ms/step - loss: 0.0030 - accuracy: 0.8142 - val_loss: 0.0036 - val_accuracy: 0.8153
# Epoch 87/100
# 79/79 [==============================] - 34s 425ms/step - loss: 0.0029 - accuracy: 0.8152 - val_loss: 0.0036 - val_accuracy: 0.7934
# Epoch 88/100
# 79/79 [==============================] - 29s 368ms/step - loss: 0.0030 - accuracy: 0.8110 - val_loss: 0.0036 - val_accuracy: 0.8077
# Epoch 89/100
# 79/79 [==============================] - 29s 364ms/step - loss: 0.0029 - accuracy: 0.8156 - val_loss: 0.0036 - val_accuracy: 0.8156
# Epoch 90/100
# 79/79 [==============================] - 34s 433ms/step - loss: 0.0030 - accuracy: 0.8108 - val_loss: 0.0038 - val_accuracy: 0.8197
# Epoch 91/100
# 79/79 [==============================] - 29s 363ms/step - loss: 0.0030 - accuracy: 0.8142 - val_loss: 0.0036 - val_accuracy: 0.8200
# Epoch 92/100
# 79/79 [==============================] - 29s 364ms/step - loss: 0.0029 - accuracy: 0.8172 - val_loss: 0.0036 - val_accuracy: 0.8130
# Epoch 93/100
# 79/79 [==============================] - 34s 432ms/step - loss: 0.0029 - accuracy: 0.8167 - val_loss: 0.0036 - val_accuracy: 0.8196
# Epoch 94/100
# 79/79 [==============================] - 29s 364ms/step - loss: 0.0029 - accuracy: 0.8164 - val_loss: 0.0036 - val_accuracy: 0.8132
# Epoch 95/100
# 79/79 [==============================] - 29s 365ms/step - loss: 0.0028 - accuracy: 0.8190 - val_loss: 0.0037 - val_accuracy: 0.8170
# Epoch 96/100
# 79/79 [==============================] - 29s 373ms/step - loss: 0.0029 - accuracy: 0.8156 - val_loss: 0.0036 - val_accuracy: 0.8241
# Epoch 97/100
# 79/79 [==============================] - 33s 423ms/step - loss: 0.0028 - accuracy: 0.8186 - val_loss: 0.0036 - val_accuracy: 0.8161
# Epoch 98/100
# 79/79 [==============================] - 29s 367ms/step - loss: 0.0029 - accuracy: 0.8181 - val_loss: 0.0036 - val_accuracy: 0.8129
# Epoch 99/100
# 79/79 [==============================] - 29s 367ms/step - loss: 0.0029 - accuracy: 0.8167 - val_loss: 0.0037 - val_accuracy: 0.8171
# Epoch 100/100
# 79/79 [==============================] - 34s 431ms/step - loss: 0.0028 - accuracy: 0.8173 - val_loss: 0.0036 - val_accuracy: 0.8204

# %%
model = tf.keras.models.load_model('pesi_rete.h5')


# Carica e pre-elabora i dati
(x_train, y_train), (x_test, y_test) = getDataset()

# Suddividi il dataset di addestramento in train e validation set
val_split = 0.05
val_samples = int(val_split * len(x_train))
X_val = x_train[-val_samples:]
y_val = y_train[-val_samples:]
x_train = x_train[:val_samples]
y_train = y_train[:val_samples]

EPOCHS = 50
BATCH_SIZE = 16  # Riduci la dimensione del batch
callbacks=[keras.callbacks.ModelCheckpoint('pesi_rete_2.h5',save_best_only=True)]

# Aggiungi un learning rate scheduler
lr_scheduler = keras.callbacks.ReduceLROnPlateau(factor=0.1, patience=10)

model.compile(optimizer=optimizers.Adam(),
              loss=losses.MeanSquaredError(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    validation_data=(X_val, y_val),
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS,
                    callbacks=[callbacks, lr_scheduler],
                    verbose=1)
# Out:
# Epoch 1/50
# 157/157 [==============================] - 41s 231ms/step - loss: 0.0042 - accuracy: 0.7788 - val_loss: 0.0036 - val_accuracy: 0.8160 - lr: 0.0010
# Epoch 2/50
# 157/157 [==============================] - 31s 200ms/step - loss: 0.0033 - accuracy: 0.8172 - val_loss: 0.0035 - val_accuracy: 0.8081 - lr: 0.0010
# Epoch 3/50
# 157/157 [==============================] - 35s 225ms/step - loss: 0.0033 - accuracy: 0.8173 - val_loss: 0.0034 - val_accuracy: 0.8181 - lr: 0.0010
# Epoch 4/50
# 157/157 [==============================] - 35s 225ms/step - loss: 0.0032 - accuracy: 0.8171 - val_loss: 0.0034 - val_accuracy: 0.8239 - lr: 0.0010
# Epoch 5/50
# 157/157 [==============================] - 30s 193ms/step - loss: 0.0032 - accuracy: 0.8184 - val_loss: 0.0036 - val_accuracy: 0.8220 - lr: 0.0010
# Epoch 6/50
# 157/157 [==============================] - 35s 225ms/step - loss: 0.0034 - accuracy: 0.8182 - val_loss: 0.0034 - val_accuracy: 0.8221 - lr: 0.0010
# Epoch 7/50
# 157/157 [==============================] - 30s 193ms/step - loss: 0.0032 - accuracy: 0.8180 - val_loss: 0.0034 - val_accuracy: 0.8194 - lr: 0.0010
# Epoch 8/50
# 157/157 [==============================] - 35s 224ms/step - loss: 0.0031 - accuracy: 0.8162 - val_loss: 0.0034 - val_accuracy: 0.8177 - lr: 0.0010
# Epoch 9/50
# 157/157 [==============================] - 30s 193ms/step - loss: 0.0032 - accuracy: 0.8153 - val_loss: 0.0035 - val_accuracy: 0.8131 - lr: 0.0010
# Epoch 10/50
# 157/157 [==============================] - 35s 225ms/step - loss: 0.0031 - accuracy: 0.8184 - val_loss: 0.0033 - val_accuracy: 0.8230 - lr: 0.0010
# Epoch 11/50
# 157/157 [==============================] - 30s 193ms/step - loss: 0.0031 - accuracy: 0.8173 - val_loss: 0.0034 - val_accuracy: 0.8036 - lr: 0.0010
# Epoch 12/50
# 157/157 [==============================] - 31s 199ms/step - loss: 0.0031 - accuracy: 0.8158 - val_loss: 0.0034 - val_accuracy: 0.8194 - lr: 0.0010
# Epoch 13/50
# 157/157 [==============================] - 34s 217ms/step - loss: 0.0030 - accuracy: 0.8186 - val_loss: 0.0034 - val_accuracy: 0.8238 - lr: 0.0010
# Epoch 14/50
# 157/157 [==============================] - 35s 225ms/step - loss: 0.0030 - accuracy: 0.8183 - val_loss: 0.0034 - val_accuracy: 0.7913 - lr: 0.0010
# Epoch 15/50
# 157/157 [==============================] - 35s 225ms/step - loss: 0.0030 - accuracy: 0.8199 - val_loss: 0.0035 - val_accuracy: 0.8085 - lr: 0.0010
# Epoch 16/50
# 157/157 [==============================] - 35s 222ms/step - loss: 0.0030 - accuracy: 0.8194 - val_loss: 0.0034 - val_accuracy: 0.8142 - lr: 0.0010
# Epoch 17/50
# 157/157 [==============================] - 35s 226ms/step - loss: 0.0030 - accuracy: 0.8217 - val_loss: 0.0033 - val_accuracy: 0.8244 - lr: 0.0010
# Epoch 18/50
# 157/157 [==============================] - 30s 193ms/step - loss: 0.0029 - accuracy: 0.8189 - val_loss: 0.0034 - val_accuracy: 0.8168 - lr: 0.0010
# Epoch 19/50
# 157/157 [==============================] - 36s 227ms/step - loss: 0.0030 - accuracy: 0.8186 - val_loss: 0.0033 - val_accuracy: 0.8181 - lr: 0.0010
# Epoch 20/50
# 157/157 [==============================] - 32s 202ms/step - loss: 0.0029 - accuracy: 0.8232 - val_loss: 0.0033 - val_accuracy: 0.8162 - lr: 0.0010
# Epoch 21/50
# 157/157 [==============================] - 32s 204ms/step - loss: 0.0028 - accuracy: 0.8268 - val_loss: 0.0033 - val_accuracy: 0.8269 - lr: 1.0000e-04
# Epoch 22/50
# 157/157 [==============================] - 35s 226ms/step - loss: 0.0027 - accuracy: 0.8282 - val_loss: 0.0033 - val_accuracy: 0.8271 - lr: 1.0000e-04
# Epoch 23/50
# 157/157 [==============================] - 31s 200ms/step - loss: 0.0027 - accuracy: 0.8284 - val_loss: 0.0033 - val_accuracy: 0.8258 - lr: 1.0000e-04
# Epoch 24/50
# 157/157 [==============================] - 35s 225ms/step - loss: 0.0027 - accuracy: 0.8288 - val_loss: 0.0033 - val_accuracy: 0.8266 - lr: 1.0000e-04
# Epoch 25/50
# 157/157 [==============================] - 34s 217ms/step - loss: 0.0027 - accuracy: 0.8288 - val_loss: 0.0033 - val_accuracy: 0.8245 - lr: 1.0000e-04
# Epoch 26/50
# 157/157 [==============================] - 31s 201ms/step - loss: 0.0027 - accuracy: 0.8292 - val_loss: 0.0033 - val_accuracy: 0.8267 - lr: 1.0000e-04
# Epoch 27/50
# 157/157 [==============================] - 31s 195ms/step - loss: 0.0027 - accuracy: 0.8292 - val_loss: 0.0033 - val_accuracy: 0.8261 - lr: 1.0000e-04
# Epoch 28/50
# 157/157 [==============================] - 30s 194ms/step - loss: 0.0027 - accuracy: 0.8297 - val_loss: 0.0033 - val_accuracy: 0.8281 - lr: 1.0000e-04
# Epoch 29/50
# 157/157 [==============================] - 33s 210ms/step - loss: 0.0027 - accuracy: 0.8295 - val_loss: 0.0033 - val_accuracy: 0.8280 - lr: 1.0000e-04
# Epoch 30/50
# 157/157 [==============================] - 36s 233ms/step - loss: 0.0027 - accuracy: 0.8295 - val_loss: 0.0033 - val_accuracy: 0.8280 - lr: 1.0000e-04
# Epoch 31/50
# 157/157 [==============================] - 34s 219ms/step - loss: 0.0026 - accuracy: 0.8299 - val_loss: 0.0033 - val_accuracy: 0.8280 - lr: 1.0000e-05
# Epoch 32/50
# 157/157 [==============================] - 31s 199ms/step - loss: 0.0026 - accuracy: 0.8299 - val_loss: 0.0033 - val_accuracy: 0.8280 - lr: 1.0000e-05
# Epoch 33/50
# 157/157 [==============================] - 34s 219ms/step - loss: 0.0026 - accuracy: 0.8300 - val_loss: 0.0033 - val_accuracy: 0.8281 - lr: 1.0000e-05
# Epoch 34/50
# 157/157 [==============================] - 31s 198ms/step - loss: 0.0026 - accuracy: 0.8302 - val_loss: 0.0033 - val_accuracy: 0.8269 - lr: 1.0000e-05
# Epoch 35/50
# 157/157 [==============================] - 34s 219ms/step - loss: 0.0026 - accuracy: 0.8299 - val_loss: 0.0033 - val_accuracy: 0.8287 - lr: 1.0000e-05
# Epoch 36/50
# 157/157 [==============================] - 31s 195ms/step - loss: 0.0026 - accuracy: 0.8302 - val_loss: 0.0033 - val_accuracy: 0.8277 - lr: 1.0000e-05
# Epoch 37/50
# 157/157 [==============================] - 31s 199ms/step - loss: 0.0026 - accuracy: 0.8302 - val_loss: 0.0033 - val_accuracy: 0.8292 - lr: 1.0000e-05
# Epoch 38/50
# 157/157 [==============================] - 30s 194ms/step - loss: 0.0026 - accuracy: 0.8302 - val_loss: 0.0033 - val_accuracy: 0.8286 - lr: 1.0000e-05
# Epoch 39/50
# 157/157 [==============================] - 35s 226ms/step - loss: 0.0026 - accuracy: 0.8302 - val_loss: 0.0033 - val_accuracy: 0.8285 - lr: 1.0000e-05
# Epoch 40/50
# 157/157 [==============================] - 30s 194ms/step - loss: 0.0026 - accuracy: 0.8303 - val_loss: 0.0033 - val_accuracy: 0.8285 - lr: 1.0000e-05
# Epoch 41/50
# 157/157 [==============================] - 35s 225ms/step - loss: 0.0026 - accuracy: 0.8304 - val_loss: 0.0033 - val_accuracy: 0.8282 - lr: 1.0000e-06
# Epoch 42/50
# 157/157 [==============================] - 30s 193ms/step - loss: 0.0026 - accuracy: 0.8304 - val_loss: 0.0033 - val_accuracy: 0.8284 - lr: 1.0000e-06
# Epoch 43/50
# 157/157 [==============================] - 35s 226ms/step - loss: 0.0026 - accuracy: 0.8302 - val_loss: 0.0033 - val_accuracy: 0.8288 - lr: 1.0000e-06
# Epoch 44/50
# 157/157 [==============================] - 35s 226ms/step - loss: 0.0026 - accuracy: 0.8304 - val_loss: 0.0033 - val_accuracy: 0.8285 - lr: 1.0000e-06
# Epoch 45/50
# 157/157 [==============================] - 35s 222ms/step - loss: 0.0026 - accuracy: 0.8303 - val_loss: 0.0033 - val_accuracy: 0.8287 - lr: 1.0000e-06
# Epoch 46/50
# 157/157 [==============================] - 35s 224ms/step - loss: 0.0026 - accuracy: 0.8303 - val_loss: 0.0033 - val_accuracy: 0.8287 - lr: 1.0000e-06
# Epoch 47/50
# 157/157 [==============================] - 31s 195ms/step - loss: 0.0026 - accuracy: 0.8303 - val_loss: 0.0033 - val_accuracy: 0.8284 - lr: 1.0000e-06
# Epoch 48/50
# 157/157 [==============================] - 36s 230ms/step - loss: 0.0026 - accuracy: 0.8306 - val_loss: 0.0033 - val_accuracy: 0.8283 - lr: 1.0000e-06
# Epoch 49/50
# 157/157 [==============================] - 30s 193ms/step - loss: 0.0026 - accuracy: 0.8304 - val_loss: 0.0033 - val_accuracy: 0.8283 - lr: 1.0000e-06
# Epoch 50/50
# 157/157 [==============================] - 35s 225ms/step - loss: 0.0026 - accuracy: 0.8303 - val_loss: 0.0033 - val_accuracy: 0.8284 - lr: 1.0000e-06
